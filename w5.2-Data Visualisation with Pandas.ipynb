#        -3.38110511e-01, -3.26877455e-02,  1.32391673e+00, -1.48014066e-01,
#        -1.61451435e+00,  1.16887916e+00, -2.23937607e+00,  1.02080358e+00,
#        -1.90758937e-01,  5.87796252e-01,  5.95008823e-01,  8.40792598e-01,
#        -3.94515993e-01,  2.02436434e+00, -3.64674536e-01,  1.87779629e-01,
#         1.20118812e+00,  3.81374145e-02, -1.59531589e+00, -2.98064599e-01,
#        -1.40728035e-01, -9.84533467e-01, -4.89092134e-01,  4.07402119e-01,
#        -4.69303747e-01,  1.88815939e+00,  8.42010025e-01, -1.54889282e+00,
#         1.07388074e+00,  9.89836491e-01,  1.25810614e+00,  1.11751004e+00,
#        -9.36152434e-01,  2.11048811e-01,  4.94763914e-03,  8.13150692e-01,
#        -1.51471173e+00,  1.92109078e+00, -1.30331819e+00,  1.12085202e+00,
#         3.52801834e-01, -1.88911864e+00,  8.83295973e-01, -1.40004220e-01,
#         7.13549928e-01, -6.90115989e-01,  1.10157686e+00, -4.82940668e-01,
#         8.36948204e-01, -4.19761443e-01, -3.64501114e-01, -1.22066141e+00,
#        -1.21757101e+00, -5.90477717e-01, -6.78485423e-01, -1.32187866e+00,
#        -2.93611089e-01,  7.88867727e-01, -2.06014569e-01,  2.13989235e+00,
#        -3.05025431e-01, -2.52034523e-01, -1.61738290e+00,  1.51355951e+00,
#         1.74466742e+00, -2.37581613e-01,  7.46833100e-01,  1.08880001e+00,
#        -1.38513869e+00, -4.16562004e-01,  1.08018391e+00, -9.23650392e-01,
#         2.76293095e-01, -1.08558290e+00, -2.05702779e+00,  5.87497351e-02,
#         9.20719954e-01, -2.03591178e-01,  4.69029945e-01,  3.90943902e-01,
#         5.34210961e-02,  1.02414185e+00,  2.03128787e+00,  7.91161175e-01,
#        -5.48553416e-01, -7.79842768e-01,  1.04011349e+00,  4.23048361e-02,
#         3.96130861e-01,  5.31332973e-01,  7.90725832e-02,  1.07516368e+00,
#        -2.19022443e+00,  1.01833438e+00,  4.66666079e-01, -3.45813920e-02,
#        -3.78348991e-01, -7.57903296e-01, -1.99973675e-01, -7.10825361e-01,
#         3.15259939e-01,  1.05009272e+00,  1.31428351e+00, -9.94930489e-01,
#         3.25967728e-01,  2.23994239e+00,  1.03004803e+00,  5.76567330e-02,
#         3.74273514e-01, -4.94724511e-01, -7.06676413e-01,  6.19156400e-01,
#         3.11350204e-01,  1.23519525e+00,  1.92040709e-01, -4.22000135e-01,
#         3.13214201e-01,  9.10667459e-01, -9.91367130e-01, -8.61869197e-01,
#        -2.10769442e+00, -5.42632177e-01,  6.07244208e-01, -1.16107436e+00])

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07 -0.361122
# 2019-06-08  0.367458
# 2019-06-09  0.859668
# 2019-06-10 -0.534867
# 2019-06-11  2.120708
# ...              ...
# 2022-02-26 -0.033565
# 2022-02-27  0.766451
# 2022-02-28  1.457095
# 2022-03-01 -0.327209
# 2022-03-02  0.831784
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  1.256029
# 2019-06-08 -0.083857
# 2019-06-09  0.595328
# 2019-06-10  0.128402
# 2019-06-11  1.259251

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  1.256029
# 2019-06-08  1.172172
# 2019-06-09  1.767501
# 2019-06-10  1.895903
# 2019-06-11  3.155154

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -1.019571
# 2019-06-08   -1.034896
# 2019-06-09   -1.595332
# 2019-06-10    0.435819
# 2019-06-11    0.379500
# Freq: D, dtype: float64

# %%
ts
# Out:
# 2019-06-07    -1.019571
# 2019-06-08    -1.034896
# 2019-06-09    -1.595332
# 2019-06-10     0.435819
# 2019-06-11     0.379500
#                 ...
# 2022-02-26   -52.140038
# 2022-02-27   -53.102380
# 2022-02-28   -54.086573
# 2022-03-01   -53.499391
# 2022-03-02   -53.136552
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts.plot(figsize=(5,5))

# %%
ts.plot(figsize=(10,5))

# %%
plt.plot(ts)

# %%
ts
# Out:
# 2019-06-07    -1.019571
# 2019-06-08    -1.034896
# 2019-06-09    -1.595332
# 2019-06-10     0.435819
# 2019-06-11     0.379500
#                 ...
# 2022-02-26   -52.140038
# 2022-02-27   -53.102380
# 2022-02-28   -54.086573
# 2022-03-01   -53.499391
# 2022-03-02   -53.136552
# Freq: D, Length: 1000, dtype: float64

# %%
df.head()
# Out:
#                value
# 2019-06-07  1.256029
# 2019-06-08  1.172172
# 2019-06-09  1.767501
# 2019-06-10  1.895903
# 2019-06-11  3.155154

# %%
df.plot(kind ='line')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
df.iloc[0].plot.barh()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic['pclass'].plot(kind = 'bar')

# %% [markdown]
# ### practice

# %%
#plot a fraph for fare price variation
#try to show survived in histogram

# %%
titanic['fare'].plot()

# %%
titanic['survived'].plot.hist()

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.567902 -0.786374  0.819718 -0.389249
# 1 -0.217950 -0.697524  2.481883  1.293478
# 2  0.348927 -1.610134  0.409615  0.314321
# 3  1.641361 -0.685722 -0.433317 -0.409607
# 4  0.547411 -0.173251 -0.508007 -0.497760
# 5  0.600855  0.378124 -0.903452 -1.509540
# 6  0.129925 -0.987288  0.708836  0.237906
# 7 -0.062526 -1.264303  0.405037  1.329826
# 8 -0.217830 -0.014963  0.541818 -0.627464
# 9 -0.833897  0.791095 -0.716617  0.546961

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.hist()

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.7, figsize=(20,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEBDCA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEBF8848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEE9AE0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEE9E2AC8>]],
#       dtype=object)

# %%
df.diff().hist(color = 'r', alpha = 0.2, figsize=(20,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEB2CB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEB4EA08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEB83188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEDB7B88>]],
#       dtype=object)

# %%
df.diff().hist(color = '#000000', alpha = 0.7, figsize=(20,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEF020C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEF24E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEEF5EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEF124088>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df = iris

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', color = 'r')

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 50, C = 'sepal_width')

# %%
d
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df = iris.drop(['species'], axis = 1)
d = df.iloc[0]

d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d.plot.pie(figsize = (5,5))

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
df.head(3).T
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (15,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEFA7E088>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEFAAF048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEF887EC8>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEF9454C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEF970C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019EEF9A2108>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8),  color = 'r',diagonal='kde')
plt.show()

# %%
df['sepal_length'].plot.kde()

# %%
df['petal_width'].plot.kde()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df,'sepal_width')

# %%
ts.plot(label = 'Series', legend = True)

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
ts.plot(style = 'r*', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A23D48E88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A242CDBC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A2429B888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A24337288>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
